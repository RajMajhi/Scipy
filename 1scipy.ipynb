# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

# %%
# Interpolation
# This will come inhandy in engineering physics lab or real world data collection. 

x = np.linspace(1, 10, 10)
y = x**2 * np.sin(x)
plt.scatter(x,y)
